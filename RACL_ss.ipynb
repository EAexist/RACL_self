# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/"2021 봄학기"/"CS475 자연언어처리를 위한 기계학습"/Project/RACL_self
# %tensorflow_version 1.x
# %pip install \
numpy \
scikit-learn \
tf_slim \
gast==0.2.2
import tensorflow
print(tensorflow.__version__)
# Out:
# /content/drive/MyDrive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (1.19.5)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (0.22.2.post1)
# Requirement already satisfied: tf_slim in /usr/local/lib/python3.7/dist-packages (1.1.0)
# Requirement already satisfied: gast==0.2.2 in /usr/local/lib/python3.7/dist-packages (0.2.2)
# Requirement already satisfied: scipy>=0.17.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn) (1.4.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn) (1.0.1)
# Requirement already satisfied: absl-py>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from tf_slim) (0.12.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from absl-py>=0.2.2->tf_slim) (1.15.0)
# 1.15.2

# %%
# %cd /content/drive/MyDrive/"2021 봄학기"/"CS475 자연언어처리를 위한 기계학습"/Project/RACL_self
# !CUDA_VISIBLE_DEVICES=0 python train_racl_kr.py --task dbsa --unlabel_ratio 0.5 --aug_num 0 --save0 0.5

#!CUDA_VISIBLE_DEVICES=0 python train_racl_kr.py --task dbsa --num_students 1 --save0 00
# !CUDA_VISIBLE_DEVICES=0 python train_racl_kr.py --task dbsa --num_students 2 --load0 1 --ckpt 00
# !CUDA_VISIBLE_DEVICES=0 python train_racl_kr.py --task dbsa --num_students 2 --load0 1 --ckpt 00
# Out:
# /content/drive/MyDrive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self
# WARNING:tensorflow:From train_racl_kr.py:95: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# Reuse Word Dictionary & Embedding
# -----------------------------------Parameters-----------------------------------
# I0604 12:29:57.803498 140636206983040 model_kr.py:42] -----------------------------------Parameters-----------------------------------
# >>> model: racl
# >>> task: dbsa
# >>> batch_size: 8
# >>> learning_rate: 0.0001
# >>> global_dim: 300
# >>> domain_dim: 0
# >>> kp1: 0.5
# >>> kp2: 0.5
# >>> reg_scale: 1e-05
# >>> filter_num: 256
# >>> class_num: 3
# >>> load0: 0
# >>> load1: 0
# >>> kernel_size: 3
# >>> hop_num: 4
# >>> n_iter: 1
# >>> aug_num: 0
# >>> num_students: 5
# >>> unlabel_ratio: 0.5
# >>> shake_ratio: 0
# >>> confidence_thresh: -1
# >>> save0: 0.5
# >>> ckpt: None
# >>> array: 100
# >>> max_sentence_len: 60
# >>> warmup_iter: 35
# >>> emb_dim: 300
# >>> data_path: data/dbsa/
# >>> train_path: data/dbsa/train_label/
# >>> test_path: data/dbsa/test/
# >>> dev_path: data/dbsa/dev/
# >>> n_iter_st: 1
# >>> unlabel_path: data/dbsa/train_unlabel/
#
#
# I0604 12:29:57.804367 140636206983040 model_kr.py:43] >>> model: racl
# >>> task: dbsa
# >>> batch_size: 8
# >>> learning_rate: 0.0001
# >>> global_dim: 300
# >>> domain_dim: 0
# >>> kp1: 0.5
# >>> kp2: 0.5
# >>> reg_scale: 1e-05
# >>> filter_num: 256
# >>> class_num: 3
# >>> load0: 0
# >>> load1: 0
# >>> kernel_size: 3
# >>> hop_num: 4
# >>> n_iter: 1
# >>> aug_num: 0
# >>> num_students: 5
# >>> unlabel_ratio: 0.5
# >>> shake_ratio: 0
# >>> confidence_thresh: -1
# >>> save0: 0.5
# >>> ckpt: None
# >>> array: 100
# >>> max_sentence_len: 60
# >>> warmup_iter: 35
# >>> emb_dim: 300
# >>> data_path: data/dbsa/
# >>> train_path: data/dbsa/train_label/
# >>> test_path: data/dbsa/test/
# >>> dev_path: data/dbsa/dev/
# >>> n_iter_st: 1
# >>> unlabel_path: data/dbsa/train_unlabel/
#
#
# WARNING:tensorflow:From /content/drive/MyDrive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/model_kr.py:51: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0604 12:29:57.819654 140636206983040 module_wrapper.py:139] From /content/drive/MyDrive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/model_kr.py:51: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /content/drive/MyDrive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/model_kr.py:72: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# W0604 12:29:57.833496 140636206983040 deprecation.py:506] From /content/drive/MyDrive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/model_kr.py:72: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /content/drive/MyDrive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/model_kr.py:75: conv1d (from tensorflow.python.layers.convolutional) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.keras.layers.Conv1D` instead.
# W0604 12:29:57.840721 140636206983040 deprecation.py:323] From /content/drive/MyDrive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/model_kr.py:75: conv1d (from tensorflow.python.layers.convolutional) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.keras.layers.Conv1D` instead.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/layers/convolutional.py:218: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# W0604 12:29:57.841373 140636206983040 deprecation.py:323] From /tensorflow-1.15.2/python3.7/tensorflow_core/python/layers/convolutional.py:218: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From /content/drive/MyDrive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/model_kr.py:95: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# W0604 12:29:57.866477 140636206983040 module_wrapper.py:139] From /content/drive/MyDrive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/model_kr.py:95: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /content/drive/MyDrive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/utils.py:425: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W0604 12:29:58.059276 140636206983040 deprecation.py:323] From /content/drive/MyDrive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/utils.py:425: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/autograph/converters/directives.py:119: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# W0604 12:29:58.277562 140636206983040 module_wrapper.py:139] From /tensorflow-1.15.2/python3.7/tensorflow_core/python/autograph/converters/directives.py:119: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/autograph/converters/directives.py:119: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0604 12:29:58.369007 140636206983040 module_wrapper.py:139] From /tensorflow-1.15.2/python3.7/tensorflow_core/python/autograph/converters/directives.py:119: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /content/drive/MyDrive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/model_kr.py:286: The name tf.trainable_variables is deprecated. Please use tf.compat.v1.trainable_variables instead.
#
# W0604 12:29:59.400124 140636206983040 module_wrapper.py:139] From /content/drive/MyDrive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/model_kr.py:286: The name tf.trainable_variables is deprecated. Please use tf.compat.v1.trainable_variables instead.
#
# >>> total parameter: 4009568
# I0604 12:29:59.400901 140636206983040 model_kr.py:288] >>> total parameter: 4009568
# WARNING:tensorflow:From /content/drive/MyDrive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/model_kr.py:298: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See `tf.nn.softmax_cross_entropy_with_logits_v2`.
#
# W0604 12:29:59.401845 140636206983040 deprecation.py:323] From /content/drive/MyDrive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/model_kr.py:298: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See `tf.nn.softmax_cross_entropy_with_logits_v2`.
#
# WARNING:tensorflow:From /content/drive/MyDrive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/model_kr.py:308: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# W0604 12:29:59.451965 140636206983040 module_wrapper.py:139] From /content/drive/MyDrive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/model_kr.py:308: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W0604 12:29:59.517954 140636206983040 deprecation.py:323] From /tensorflow-1.15.2/python3.7/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /content/drive/MyDrive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/model_kr.py:320: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# W0604 12:30:02.261328 140636206983040 module_wrapper.py:139] From /content/drive/MyDrive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/model_kr.py:320: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# ## unlabel size ## 636
# WARNING:tensorflow:From /content/drive/MyDrive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/model_kr.py:332: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# W0604 12:30:03.653289 140636206983040 module_wrapper.py:139] From /content/drive/MyDrive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/model_kr.py:332: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /content/drive/MyDrive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/model_kr.py:334: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# W0604 12:30:03.894343 140636206983040 module_wrapper.py:139] From /content/drive/MyDrive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/model_kr.py:334: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
#
# META EPOCH 0 | -------------------------------------Iter0--------------------------------------
# I0604 12:30:15.740027 140636206983040 model_kr.py:454]
# META EPOCH 0 | -------------------------------------Iter0--------------------------------------
# Train: final loss=218.766492, aspect loss=101.045232, opinion loss=104.479830, sentiment loss=13.219918, reg loss=2151.124408, step=159
# I0604 12:30:15.740632 140636206983040 model_kr.py:249] Train: final loss=218.766492, aspect loss=101.045232, opinion loss=104.479830, sentiment loss=13.219918, reg loss=2151.124408, step=159
# Dev: final loss=57.483034, aspect loss=26.667287, opinion loss=27.228317, sentiment loss=3.581070, reg loss=635.995384, step=159
# I0604 12:30:15.740858 140636206983040 model_kr.py:249] Dev: final loss=57.483034, aspect loss=26.667287, opinion loss=27.228317, sentiment loss=3.581070, reg loss=635.995384, step=159
# Dev:   aspect f1=0.0000, opinion f1=0.0000, sentiment acc==0.0000, sentiment f1==0.0000, ABSA f1==0.0000,
# I0604 12:30:15.741045 140636206983040 model_kr.py:244] Dev:   aspect f1=0.0000, opinion f1=0.0000, sentiment acc==0.0000, sentiment f1==0.0000, ABSA f1==0.0000,
# Test:   aspect f1=0.0000, opinion f1=0.0000, sentiment acc==0.0000, sentiment f1==0.0000, ABSA f1==0.0000,
# I0604 12:30:15.741226 140636206983040 model_kr.py:244] Test:   aspect f1=0.0000, opinion f1=0.0000, sentiment acc==0.0000, sentiment f1==0.0000, ABSA f1==0.0000,
# Predict unlabeled:   aspect f1=0.0000, opinion f1=0.0000, sentiment acc==0.0000, sentiment f1==0.0000, ABSA f1==0.0000,
# I0604 12:30:15.741384 140636206983040 model_kr.py:244] Predict unlabeled:   aspect f1=0.0000, opinion f1=0.0000, sentiment acc==0.0000, sentiment f1==0.0000, ABSA f1==0.0000,
# Current Max Metrics Index : 0 Current Min Loss Index : 0 Epoch Time: 0m 8s
# I0604 12:30:15.741541 140636206983040 model_kr.py:253] Current Max Metrics Index : 0 Current Min Loss Index : 0 Epoch Time: 0m 8s
#
# META EPOCH 0 | --------------------------------Mission Complete--------------------------------
# I0604 12:30:15.741698 140636206983040 model_kr.py:460]
# META EPOCH 0 | --------------------------------Mission Complete--------------------------------
# Dev Max Metrics Index: 0
# I0604 12:30:15.741851 140636206983040 model_kr.py:463] Dev Max Metrics Index: 0
# TEST |:   aspect f1=0.0000, opinion f1=0.0000, sentiment acc==0.0000, sentiment f1==0.0000, ABSA f1==0.0000,
# I0604 12:30:15.742004 140636206983040 model_kr.py:244] TEST |:   aspect f1=0.0000, opinion f1=0.0000, sentiment acc==0.0000, sentiment f1==0.0000, ABSA f1==0.0000,
# PREDICT UNLABELED |:   aspect f1=0.0000, opinion f1=0.0000, sentiment acc==0.0000, sentiment f1==0.0000, ABSA f1==0.0000,
# I0604 12:30:15.742303 140636206983040 model_kr.py:244] PREDICT UNLABELED |:   aspect f1=0.0000, opinion f1=0.0000, sentiment acc==0.0000, sentiment f1==0.0000, ABSA f1==0.0000,
# Dev Min Loss Index: 0
# I0604 12:30:15.742580 140636206983040 model_kr.py:471] Dev Min Loss Index: 0
# TEST |:   aspect f1=0.0000, opinion f1=0.0000, sentiment acc==0.0000, sentiment f1==0.0000, ABSA f1==0.0000,
# I0604 12:30:15.742766 140636206983040 model_kr.py:244] TEST |:   aspect f1=0.0000, opinion f1=0.0000, sentiment acc==0.0000, sentiment f1==0.0000, ABSA f1==0.0000,
# PREDICT UNLABELED |:   aspect f1=0.0000, opinion f1=0.0000, sentiment acc==0.0000, sentiment f1==0.0000, ABSA f1==0.0000,
# I0604 12:30:15.742923 140636206983040 model_kr.py:244] PREDICT UNLABELED |:   aspect f1=0.0000, opinion f1=0.0000, sentiment acc==0.0000, sentiment f1==0.0000, ABSA f1==0.0000,
# Confident feature ratio of predict unlabeled: threshold = -1.0000, aspect = 6.0047, opinion = 6.0047, sentiment = 6.0047
# I0604 12:30:16.351440 140636206983040 model_kr.py:534] Confident feature ratio of predict unlabeled: threshold = -1.0000, aspect = 6.0047, opinion = 6.0047, sentiment = 6.0047
#
# META EPOCH 1 | -------------------------------------Iter0--------------------------------------
# I0604 12:30:27.268293 140636206983040 model_kr.py:641]
# META EPOCH 1 | -------------------------------------Iter0--------------------------------------
# Train: final loss=263.556352, aspect loss=116.342493, opinion loss=119.811504, sentiment loss=27.370023, reg loss=3233.114954, step=239
# I0604 12:30:27.268782 140636206983040 model_kr.py:249] Train: final loss=263.556352, aspect loss=116.342493, opinion loss=119.811504, sentiment loss=27.370023, reg loss=3233.114954, step=239
# Dev: final loss=58.907607, aspect loss=27.196377, opinion loss=28.082474, sentiment loss=3.622381, reg loss=637.694988, step=239
# I0604 12:30:27.269002 140636206983040 model_kr.py:249] Dev: final loss=58.907607, aspect loss=27.196377, opinion loss=28.082474, sentiment loss=3.622381, reg loss=637.694988, step=239
# Dev:   aspect f1=0.0000, opinion f1=0.0000, sentiment acc==0.0000, sentiment f1==0.0000, ABSA f1==0.0000,
# I0604 12:30:27.269216 140636206983040 model_kr.py:244] Dev:   aspect f1=0.0000, opinion f1=0.0000, sentiment acc==0.0000, sentiment f1==0.0000, ABSA f1==0.0000,
# Test:   aspect f1=0.0000, opinion f1=0.0000, sentiment acc==0.0000, sentiment f1==0.0000, ABSA f1==0.0000,
# I0604 12:30:27.269389 140636206983040 model_kr.py:244] Test:   aspect f1=0.0000, opinion f1=0.0000, sentiment acc==0.0000, sentiment f1==0.0000, ABSA f1==0.0000,
# Predict unlabeled:   aspect f1=0.0000, opinion f1=0.0000, sentiment acc==0.0000, sentiment f1==0.0000, ABSA f1==0.0000,
# I0604 12:30:27.269549 140636206983040 model_kr.py:244] Predict unlabeled:   aspect f1=0.0000, opinion f1=0.0000, sentiment acc==0.0000, sentiment f1==0.0000, ABSA f1==0.0000,
# Current Max Metrics Index : 0 Current Min Loss Index : 0 Epoch Time: 0m 9s
# I0604 12:30:27.269706 140636206983040 model_kr.py:253] Current Max Metrics Index : 0 Current Min Loss Index : 0 Epoch Time: 0m 9s
#
# META EPOCH 1 | --------------------------------Mission Complete--------------------------------
# I0604 12:30:27.269862 140636206983040 model_kr.py:647]
# META EPOCH 1 | --------------------------------Mission Complete--------------------------------
# Dev Max Metrics Index: 0
# I0604 12:30:27.270012 140636206983040 model_kr.py:650] Dev Max Metrics Index: 0
# TEST |:   aspect f1=0.0000, opinion f1=0.0000, sentiment acc==0.0000, sentiment f1==0.0000, ABSA f1==0.0000,
# I0604 12:30:27.270170 140636206983040 model_kr.py:244] TEST |:   aspect f1=0.0000, opinion f1=0.0000, sentiment acc==0.0000, sentiment f1==0.0000, ABSA f1==0.0000,
# PREDICT UNLABELED |:   aspect f1=0.0000, opinion f1=0.0000, sentiment acc==0.0000, sentiment f1==0.0000, ABSA f1==0.0000,
# I0604 12:30:27.270348 140636206983040 model_kr.py:244] PREDICT UNLABELED |:   aspect f1=0.0000, opinion f1=0.0000, sentiment acc==0.0000, sentiment f1==0.0000, ABSA f1==0.0000,
# Dev Min Metrics Index: 0
# I0604 12:30:27.270502 140636206983040 model_kr.py:658] Dev Min Metrics Index: 0
# TEST |:   aspect f1=0.0000, opinion f1=0.0000, sentiment acc==0.0000, sentiment f1==0.0000, ABSA f1==0.0000,
# I0604 12:30:27.270654 140636206983040 model_kr.py:244] TEST |:   aspect f1=0.0000, opinion f1=0.0000, sentiment acc==0.0000, sentiment f1==0.0000, ABSA f1==0.0000,
# PREDICT UNLABELED |:   aspect f1=0.0000, opinion f1=0.0000, sentiment acc==0.0000, sentiment f1==0.0000, ABSA f1==0.0000,
# I0604 12:30:27.270819 140636206983040 model_kr.py:244] PREDICT UNLABELED |:   aspect f1=0.0000, opinion f1=0.0000, sentiment acc==0.0000, sentiment f1==0.0000, ABSA f1==0.0000,
# Confident feature ratio of predict unlabeled: threshold = -1.0000, aspect = 6.0047, opinion = 6.0047, sentiment = 6.0047
# I0604 12:30:27.945457 140636206983040 model_kr.py:534] Confident feature ratio of predict unlabeled: threshold = -1.0000, aspect = 6.0047, opinion = 6.0047, sentiment = 6.0047
# Traceback (most recent call last):
#   File "train_racl_kr.py", line 95, in <module>
#     tf.app.run()
#   File "/tensorflow-1.15.2/python3.7/tensorflow_core/python/platform/app.py", line 40, in run
#     _run(main=main, argv=argv, flags_parser=_parse_flags_tolerate_undef)
#   File "/usr/local/lib/python3.7/dist-packages/absl/app.py", line 303, in run
#     _run_main(main, args)
#   File "/usr/local/lib/python3.7/dist-packages/absl/app.py", line 251, in _run_main
#     sys.exit(main(argv))
#   File "train_racl_kr.py", line 90, in main
#     model.run()
#   File "/content/drive/MyDrive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/model_kr.py", line 545, in run
#     [cost, aspect_cost, opinion_cost, sentiment_cost, reg_cost, optimizer, global_step], feed_dict=train)
#   File "/tensorflow-1.15.2/python3.7/tensorflow_core/python/client/session.py", line 956, in run
#     run_metadata_ptr)
#   File "/tensorflow-1.15.2/python3.7/tensorflow_core/python/client/session.py", line 1180, in _run
#     feed_dict_tensor, options, run_metadata)
#   File "/tensorflow-1.15.2/python3.7/tensorflow_core/python/client/session.py", line 1359, in _do_run
#     run_metadata)
#   File "/tensorflow-1.15.2/python3.7/tensorflow_core/python/client/session.py", line 1365, in _do_call
#     return fn(*args)
#   File "/tensorflow-1.15.2/python3.7/tensorflow_core/python/client/session.py", line 1350, in _run_fn
#     target_list, run_metadata)
#   File "/tensorflow-1.15.2/python3.7/tensorflow_core/python/client/session.py", line 1443, in _call_tf_sessionrun
#     run_metadata)
# KeyboardInterrupt

# %%
# %cd /content/drive/MyDrive/"2021 봄학기"/"CS475 자연언어처리를 위한 기계학습"/Project/RACL_self
# !CUDA_VISIBLE_DEVICES=0 python train_racl_copy.py --task res14 --num_students 0 --unlabeled_ratio 0 --shake_ratio 0
# !CUDA_VISIBLE_DEVICES=0 python train_racl.py --task res14  --num_students 0 --shake_ratio 0.05 --save0 0.05_1
# !CUDA_VISIBLE_DEVICES=0 python train_racl.py --task res14 --num_students 0 --shake_ratio 0.05 --save0 0
# Out:
# /content/drive/MyDrive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self
# WARNING:tensorflow:From train_racl_copy.py:86: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# Reuse Word Dictionary & Embedding
# -----------------------------------Parameters-----------------------------------
# I0604 07:16:50.493366 139888831305600 model_kr.py:42] -----------------------------------Parameters-----------------------------------
# >>> model: racl
# >>> task: res14
# >>> batch_size: 8
# >>> learning_rate: 0.0001
# >>> global_dim: 300
# >>> domain_dim: 0
# >>> kp1: 0.5
# >>> kp2: 0.5
# >>> reg_scale: 1e-05
# >>> filter_num: 256
# >>> class_num: 3
# >>> load0: 0
# >>> load1: 0
# >>> num_students: 0
# >>> unlabeled_ratio: 0.0
# >>> shake_ratio: 0.0
# >>> confidence_thresh: -1
# >>> save0: None
# >>> ckpt: None
# >>> array: 100
# >>> max_sentence_len: 80
# >>> n_iter: 80
# >>> kernel_size: 3
# >>> hop_num: 4
# >>> warmup_iter: 60
# >>> emb_dim: 300
# >>> data_path: data/res14/
# >>> train_path: data/res14/train_label/
# >>> test_path: data/res14/test/
# >>> dev_path: data/res14/dev/
# >>> n_iter_st: 80
# >>> unlabel_path: data/res14/train_unlabel/
# >>> aug_num: 1
#
#
# I0604 07:16:50.494160 139888831305600 model_kr.py:43] >>> model: racl
# >>> task: res14
# >>> batch_size: 8
# >>> learning_rate: 0.0001
# >>> global_dim: 300
# >>> domain_dim: 0
# >>> kp1: 0.5
# >>> kp2: 0.5
# >>> reg_scale: 1e-05
# >>> filter_num: 256
# >>> class_num: 3
# >>> load0: 0
# >>> load1: 0
# >>> num_students: 0
# >>> unlabeled_ratio: 0.0
# >>> shake_ratio: 0.0
# >>> confidence_thresh: -1
# >>> save0: None
# >>> ckpt: None
# >>> array: 100
# >>> max_sentence_len: 80
# >>> n_iter: 80
# >>> kernel_size: 3
# >>> hop_num: 4
# >>> warmup_iter: 60
# >>> emb_dim: 300
# >>> data_path: data/res14/
# >>> train_path: data/res14/train_label/
# >>> test_path: data/res14/test/
# >>> dev_path: data/res14/dev/
# >>> n_iter_st: 80
# >>> unlabel_path: data/res14/train_unlabel/
# >>> aug_num: 1
#
#
# WARNING:tensorflow:From /content/drive/MyDrive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/model_kr.py:51: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0604 07:16:50.511769 139888831305600 module_wrapper.py:139] From /content/drive/MyDrive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/model_kr.py:51: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /content/drive/MyDrive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/model_kr.py:72: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# W0604 07:16:50.525915 139888831305600 deprecation.py:506] From /content/drive/MyDrive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/model_kr.py:72: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /content/drive/MyDrive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/model_kr.py:75: conv1d (from tensorflow.python.layers.convolutional) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.keras.layers.Conv1D` instead.
# W0604 07:16:50.533511 139888831305600 deprecation.py:323] From /content/drive/MyDrive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/model_kr.py:75: conv1d (from tensorflow.python.layers.convolutional) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.keras.layers.Conv1D` instead.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/layers/convolutional.py:218: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# W0604 07:16:50.534370 139888831305600 deprecation.py:323] From /tensorflow-1.15.2/python3.7/tensorflow_core/python/layers/convolutional.py:218: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From /content/drive/MyDrive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/model_kr.py:95: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# W0604 07:16:50.562587 139888831305600 module_wrapper.py:139] From /content/drive/MyDrive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/model_kr.py:95: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /content/drive/MyDrive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/utils.py:499: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W0604 07:16:50.747601 139888831305600 deprecation.py:323] From /content/drive/MyDrive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/utils.py:499: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/autograph/converters/directives.py:119: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# W0604 07:16:50.974277 139888831305600 module_wrapper.py:139] From /tensorflow-1.15.2/python3.7/tensorflow_core/python/autograph/converters/directives.py:119: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/autograph/converters/directives.py:119: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0604 07:16:51.060863 139888831305600 module_wrapper.py:139] From /tensorflow-1.15.2/python3.7/tensorflow_core/python/autograph/converters/directives.py:119: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /content/drive/MyDrive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/model_kr.py:306: The name tf.trainable_variables is deprecated. Please use tf.compat.v1.trainable_variables instead.
#
# W0604 07:16:52.132548 139888831305600 module_wrapper.py:139] From /content/drive/MyDrive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/model_kr.py:306: The name tf.trainable_variables is deprecated. Please use tf.compat.v1.trainable_variables instead.
#
# >>> total parameter: 4009568
# I0604 07:16:52.133280 139888831305600 model_kr.py:308] >>> total parameter: 4009568
# WARNING:tensorflow:From /content/drive/MyDrive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/model_kr.py:318: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See `tf.nn.softmax_cross_entropy_with_logits_v2`.
#
# W0604 07:16:52.134209 139888831305600 deprecation.py:323] From /content/drive/MyDrive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/model_kr.py:318: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See `tf.nn.softmax_cross_entropy_with_logits_v2`.
#
# WARNING:tensorflow:From /content/drive/MyDrive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/model_kr.py:329: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# W0604 07:16:52.184660 139888831305600 module_wrapper.py:139] From /content/drive/MyDrive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/model_kr.py:329: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W0604 07:16:52.245776 139888831305600 deprecation.py:323] From /tensorflow-1.15.2/python3.7/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /content/drive/MyDrive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/model_kr.py:341: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# W0604 07:16:55.022622 139888831305600 module_wrapper.py:139] From /content/drive/MyDrive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/model_kr.py:341: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# (488, 80) <class 'numpy.ndarray'> <class 'numpy.ndarray'>
# (488, 80) <class 'numpy.ndarray'> <class 'numpy.ndarray'>
# (488, 80) <class 'numpy.ndarray'> <class 'numpy.ndarray'>
# (488, 80, 80) <class 'numpy.ndarray'> <class 'numpy.ndarray'>
# (488, 80, 3) <class 'numpy.ndarray'> <class 'numpy.ndarray'>
# (488, 80, 3) <class 'numpy.ndarray'> <class 'numpy.ndarray'>
# (488, 80, 3) <class 'numpy.ndarray'> <class 'numpy.ndarray'>
# (488, 80) <class 'numpy.ndarray'> <class 'numpy.ndarray'>
# (488, 80) <class 'numpy.ndarray'> <class 'numpy.ndarray'>
# (488, 80) <class 'numpy.ndarray'> <class 'numpy.ndarray'>
# (488, 80) <class 'numpy.ndarray'> <class 'numpy.ndarray'>
# WARNING:tensorflow:From /content/drive/MyDrive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/model_kr.py:356: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# W0604 07:16:57.101210 139888831305600 module_wrapper.py:139] From /content/drive/MyDrive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/model_kr.py:356: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /content/drive/MyDrive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/model_kr.py:358: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# W0604 07:16:57.333742 139888831305600 module_wrapper.py:139] From /content/drive/MyDrive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/model_kr.py:358: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
#
# META EPOCH 0 | -------------------------------------Iter0--------------------------------------
# I0604 07:17:06.205694 139888831305600 model_kr.py:479]
# META EPOCH 0 | -------------------------------------Iter0--------------------------------------
# Train: final loss=100.890531, aspect loss=49.765019, opinion loss=42.126597, sentiment loss=8.990865, reg loss=805.120089, step=61
# I0604 07:17:06.206298 139888831305600 model_kr.py:269] Train: final loss=100.890531, aspect loss=49.765019, opinion loss=42.126597, sentiment loss=8.990865, reg loss=805.120089, step=61
# Dev: final loss=108.758444, aspect loss=54.974887, opinion loss=42.596257, sentiment loss=11.178192, reg loss=911.111885, step=61
# I0604 07:17:06.206532 139888831305600 model_kr.py:269] Dev: final loss=108.758444, aspect loss=54.974887, opinion loss=42.596257, sentiment loss=11.178192, reg loss=911.111885, step=61
# Dev:   aspect f1=0.0000, opinion f1=0.0000, sentiment acc==0.0000, sentiment f1==0.0000, ABSA f1==0.0000,
# I0604 07:17:06.206722 139888831305600 model_kr.py:264] Dev:   aspect f1=0.0000, opinion f1=0.0000, sentiment acc==0.0000, sentiment f1==0.0000, ABSA f1==0.0000,
# Test:   aspect f1=0.0000, opinion f1=0.0000, sentiment acc==0.0000, sentiment f1==0.0000, ABSA f1==0.0000,
# I0604 07:17:06.206905 139888831305600 model_kr.py:264] Test:   aspect f1=0.0000, opinion f1=0.0000, sentiment acc==0.0000, sentiment f1==0.0000, ABSA f1==0.0000,
# Predict unlabeled:   aspect f1=0.0000, opinion f1=0.0000, sentiment acc==0.0000, sentiment f1==0.0000, ABSA f1==0.0000,
# I0604 07:17:06.207064 139888831305600 model_kr.py:264] Predict unlabeled:   aspect f1=0.0000, opinion f1=0.0000, sentiment acc==0.0000, sentiment f1==0.0000, ABSA f1==0.0000,
# Current Max Metrics Index : 0 Current Min Loss Index : 0 Epoch Time: 0m 5s
# I0604 07:17:06.207247 139888831305600 model_kr.py:273] Current Max Metrics Index : 0 Current Min Loss Index : 0 Epoch Time: 0m 5s
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/contextlib.py", line 130, in __exit__
#     self.gen.throw(type, value, traceback)
#   File "/tensorflow-1.15.2/python3.7/tensorflow_core/python/framework/ops.py", line 5480, in get_controller
#     yield g
#   File "/content/drive/MyDrive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/model_kr.py", line 441, in run
#     pr_f1_list = get_metric(pr_a_labels, pr_a_preds, pr_o_labels, pr_o_preds, pr_s_labels, pr_s_preds, pr_final_mask, 1)
#   File "/content/drive/MyDrive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/evaluation.py", line 146, in get_metric
#     true_opinion, _ = convert_to_list(y_true_opinion, y_true_sentiment, mask)
#   File "/content/drive/MyDrive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/evaluation.py", line 20, in convert_to_list
#     if not np.any(label_dist_s):
#   File "<__array_function__ internals>", line 6, in any
#   File "/usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py", line 2330, in any
#     return _wrapreduction(a, np.logical_or, 'any', axis, None, out, keepdims=keepdims)
#   File "/usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py", line 87, in _wrapreduction
#     return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "train_racl_copy.py", line 86, in <module>
#     tf.app.run()
#   File "/tensorflow-1.15.2/python3.7/tensorflow_core/python/platform/app.py", line 40, in run
#     _run(main=main, argv=argv, flags_parser=_parse_flags_tolerate_undef)
#   File "/usr/local/lib/python3.7/dist-packages/absl/app.py", line 303, in run
#     _run_main(main, args)
#   File "/usr/local/lib/python3.7/dist-packages/absl/app.py", line 251, in _run_main
#     sys.exit(main(argv))
#   File "train_racl_copy.py", line 81, in main
#     model.run()
#   File "/content/drive/MyDrive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/model_kr.py", line 509, in run
#     writer.write('{}\n{}\n{}\n'.format(pred_ay==true_ay, pred_oy==true_oy, pred_sy==true_sy))
#   File "/tensorflow-1.15.2/python3.7/tensorflow_core/python/client/session.py", line 1633, in __exit__
#     close_thread.start()
#   File "/usr/lib/python3.7/threading.py", line 857, in start
#     self._started.wait()
#   File "/usr/lib/python3.7/threading.py", line 552, in wait
#     signaled = self._cond.wait(timeout)
#   File "/usr/lib/python3.7/threading.py", line 296, in wait
#     waiter.acquire()
# KeyboardInterrupt

# %%
# %cd /content/drive/MyDrive/"2021 봄학기"/"CS475 자연언어처리를 위한 기계학습"/Project/RACL_self
# !CUDA_VISIBLE_DEVICES=0 python train_racl_hj.py --task res14
# Out:
# /content/drive/MyDrive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self
# WARNING:tensorflow:From train_racl_hj.py:71: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# Reuse Word Dictionary & Embedding
# -----------------------------------Parameters-----------------------------------
# I0603 04:14:44.119309 139927148504960 model_hj.py:38] -----------------------------------Parameters-----------------------------------
# >>> model: racl
# >>> task: res14
# >>> batch_size: 8
# >>> learning_rate: 0.0001
# >>> global_dim: 300
# >>> domain_dim: 100
# >>> kp1: 0.5
# >>> kp2: 0.5
# >>> reg_scale: 1e-05
# >>> filter_num: 256
# >>> class_num: 3
# >>> load: 0
# >>> max_sentence_len: 80
# >>> n_iter: 10
# >>> kernel_size: 3
# >>> hop_num: 4
# >>> warmup_iter: 5
# >>> emb_dim: 400
# >>> num_students: 5
# >>> unlabeled_ratio: 0.7
# >>> shake_ratio: 0.5
# >>> data_path: data/res14/
# >>> train_path: data/res14/train/
# >>> test_path: data/res14/test/
# >>> dev_path: data/res14/dev/
#
#
# I0603 04:14:44.120175 139927148504960 model_hj.py:39] >>> model: racl
# >>> task: res14
# >>> batch_size: 8
# >>> learning_rate: 0.0001
# >>> global_dim: 300
# >>> domain_dim: 100
# >>> kp1: 0.5
# >>> kp2: 0.5
# >>> reg_scale: 1e-05
# >>> filter_num: 256
# >>> class_num: 3
# >>> load: 0
# >>> max_sentence_len: 80
# >>> n_iter: 10
# >>> kernel_size: 3
# >>> hop_num: 4
# >>> warmup_iter: 5
# >>> emb_dim: 400
# >>> num_students: 5
# >>> unlabeled_ratio: 0.7
# >>> shake_ratio: 0.5
# >>> data_path: data/res14/
# >>> train_path: data/res14/train/
# >>> test_path: data/res14/test/
# >>> dev_path: data/res14/dev/
#
#
# WARNING:tensorflow:From /content/drive/MyDrive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/model_hj.py:46: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0603 04:14:44.144668 139927148504960 module_wrapper.py:139] From /content/drive/MyDrive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/model_hj.py:46: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /content/drive/MyDrive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/model_hj.py:63: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# W0603 04:14:44.160486 139927148504960 deprecation.py:506] From /content/drive/MyDrive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/model_hj.py:63: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /content/drive/MyDrive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/model_hj.py:66: conv1d (from tensorflow.python.layers.convolutional) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.keras.layers.Conv1D` instead.
# W0603 04:14:44.167950 139927148504960 deprecation.py:323] From /content/drive/MyDrive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/model_hj.py:66: conv1d (from tensorflow.python.layers.convolutional) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.keras.layers.Conv1D` instead.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/layers/convolutional.py:218: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# W0603 04:14:44.168653 139927148504960 deprecation.py:323] From /tensorflow-1.15.2/python3.7/tensorflow_core/python/layers/convolutional.py:218: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From /content/drive/MyDrive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/model_hj.py:87: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# W0603 04:14:44.194168 139927148504960 module_wrapper.py:139] From /content/drive/MyDrive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/model_hj.py:87: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /content/drive/MyDrive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/utils.py:459: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W0603 04:14:44.390197 139927148504960 deprecation.py:323] From /content/drive/MyDrive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/utils.py:459: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/autograph/converters/directives.py:119: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# W0603 04:14:44.614463 139927148504960 module_wrapper.py:139] From /tensorflow-1.15.2/python3.7/tensorflow_core/python/autograph/converters/directives.py:119: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/autograph/converters/directives.py:119: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0603 04:14:44.701056 139927148504960 module_wrapper.py:139] From /tensorflow-1.15.2/python3.7/tensorflow_core/python/autograph/converters/directives.py:119: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /content/drive/MyDrive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/model_hj.py:215: The name tf.trainable_variables is deprecated. Please use tf.compat.v1.trainable_variables instead.
#
# W0603 04:14:45.789710 139927148504960 module_wrapper.py:139] From /content/drive/MyDrive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/model_hj.py:215: The name tf.trainable_variables is deprecated. Please use tf.compat.v1.trainable_variables instead.
#
# >>> total parameter: 5074868
# I0603 04:14:45.790472 139927148504960 model_hj.py:217] >>> total parameter: 5074868
# WARNING:tensorflow:From /content/drive/MyDrive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/model_hj.py:220: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See `tf.nn.softmax_cross_entropy_with_logits_v2`.
#
# W0603 04:14:45.791356 139927148504960 deprecation.py:323] From /content/drive/MyDrive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/model_hj.py:220: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See `tf.nn.softmax_cross_entropy_with_logits_v2`.
#
# WARNING:tensorflow:From /content/drive/MyDrive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/model_hj.py:230: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# W0603 04:14:45.841254 139927148504960 module_wrapper.py:139] From /content/drive/MyDrive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/model_hj.py:230: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W0603 04:14:45.902284 139927148504960 deprecation.py:323] From /tensorflow-1.15.2/python3.7/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /content/drive/MyDrive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/model_hj.py:242: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# W0603 04:14:48.696538 139927148504960 module_wrapper.py:139] From /content/drive/MyDrive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/model_hj.py:242: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# Traceback (most recent call last):
#   File "train_racl_hj.py", line 71, in <module>
#     tf.app.run()
#   File "/tensorflow-1.15.2/python3.7/tensorflow_core/python/platform/app.py", line 40, in run
#     _run(main=main, argv=argv, flags_parser=_parse_flags_tolerate_undef)
#   File "/usr/local/lib/python3.7/dist-packages/absl/app.py", line 303, in run
#     _run_main(main, args)
#   File "/usr/local/lib/python3.7/dist-packages/absl/app.py", line 251, in _run_main
#     sys.exit(main(argv))
#   File "train_racl_hj.py", line 66, in main
#     model.run()
#   File "/content/drive/MyDrive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/model_hj.py", line 248, in run
#     self.opt.max_sentence_len, unlabeled_ratio=self.opt.unlabeled_ratio)
# TypeError: read_data() got an unexpected keyword argument 'unlabeled_ratio'

# %%
# %cd /content/drive/MyDrive/"2021 봄학기"/"CS475 자연언어처리를 위한 기계학습"/Project/RACL_self
# !CUDA_VISIBLE_DEVICES=0 python train_racl.py --task res14 --load0 1 --ckpt 1 --num_students 4 --shake_ratio 0.2 --confidence_thresh 0.4 --save0 0
# !CUDA_VISIBLE_DEVICES=0 python train_racl.py --task res14 --load0 1 --ckpt 1 --num_students 4 --shake_ratio 0.1 --confidence_thresh 0.4 --save0 0
# !CUDA_VISIBLE_DEVICES=0 python train_racl.py --task res14 --load0 1 --ckpt 1 --num_students 4 --shake_ratio 0 --confidence_thresh 0.4 --save0 0
# Out:
# /content/drive/MyDrive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self
# WARNING:tensorflow:From train_racl.py:86: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# Label / Unlabel Split
# sentence: labeled: 488, unlabeled: 1948
#
# target_polarity: labeled: 488, unlabeled: 1948
#
# target: labeled: 488, unlabeled: 1948
#
# opinion: labeled: 488, unlabeled: 1948
#
# Reuse Word Dictionary & Embedding
# -----------------------------------Parameters-----------------------------------
# I0603 04:14:52.202291 140665196312448 model.py:38] -----------------------------------Parameters-----------------------------------
# >>> model: racl
# >>> task: res14
# >>> batch_size: 8
# >>> learning_rate: 0.0001
# >>> global_dim: 300
# >>> domain_dim: 100
# >>> kp1: 0.5
# >>> kp2: 0.5
# >>> reg_scale: 1e-05
# >>> filter_num: 256
# >>> class_num: 3
# >>> load0: 1
# >>> load1: 0
# >>> num_students: 4
# >>> unlabeled_ratio: 0.8
# >>> shake_ratio: 0.2
# >>> confidence_thresh: 0.4
# >>> save0: 0
# >>> ckpt: 1
# >>> max_sentence_len: 80
# >>> n_iter: 80
# >>> kernel_size: 3
# >>> hop_num: 4
# >>> warmup_iter: 50
# >>> emb_dim: 400
# >>> data_path: data/res14/
# >>> train_path: data/res14/train_label/
# >>> test_path: data/res14/test/
# >>> dev_path: data/res14/dev/
# >>> n_iter_st: 80
# >>> unlabel_path: data/res14/train_unlabel/
#
#
# I0603 04:14:52.203029 140665196312448 model.py:39] >>> model: racl
# >>> task: res14
# >>> batch_size: 8
# >>> learning_rate: 0.0001
# >>> global_dim: 300
# >>> domain_dim: 100
# >>> kp1: 0.5
# >>> kp2: 0.5
# >>> reg_scale: 1e-05
# >>> filter_num: 256
# >>> class_num: 3
# >>> load0: 1
# >>> load1: 0
# >>> num_students: 4
# >>> unlabeled_ratio: 0.8
# >>> shake_ratio: 0.2
# >>> confidence_thresh: 0.4
# >>> save0: 0
# >>> ckpt: 1
# >>> max_sentence_len: 80
# >>> n_iter: 80
# >>> kernel_size: 3
# >>> hop_num: 4
# >>> warmup_iter: 50
# >>> emb_dim: 400
# >>> data_path: data/res14/
# >>> train_path: data/res14/train_label/
# >>> test_path: data/res14/test/
# >>> dev_path: data/res14/dev/
# >>> n_iter_st: 80
# >>> unlabel_path: data/res14/train_unlabel/
#
#
# WARNING:tensorflow:From /content/drive/MyDrive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/model.py:46: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0603 04:14:52.226197 140665196312448 module_wrapper.py:139] From /content/drive/MyDrive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/model.py:46: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /content/drive/MyDrive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/model.py:67: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# W0603 04:14:52.242811 140665196312448 deprecation.py:506] From /content/drive/MyDrive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/model.py:67: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /content/drive/MyDrive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/model.py:70: conv1d (from tensorflow.python.layers.convolutional) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.keras.layers.Conv1D` instead.
# W0603 04:14:52.250262 140665196312448 deprecation.py:323] From /content/drive/MyDrive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/model.py:70: conv1d (from tensorflow.python.layers.convolutional) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.keras.layers.Conv1D` instead.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/layers/convolutional.py:218: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# W0603 04:14:52.250989 140665196312448 deprecation.py:323] From /tensorflow-1.15.2/python3.7/tensorflow_core/python/layers/convolutional.py:218: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From /content/drive/MyDrive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/model.py:91: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# W0603 04:14:52.277487 140665196312448 module_wrapper.py:139] From /content/drive/MyDrive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/model.py:91: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /content/drive/MyDrive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/utils.py:459: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W0603 04:14:52.479764 140665196312448 deprecation.py:323] From /content/drive/MyDrive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/utils.py:459: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/autograph/converters/directives.py:119: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# W0603 04:14:52.707407 140665196312448 module_wrapper.py:139] From /tensorflow-1.15.2/python3.7/tensorflow_core/python/autograph/converters/directives.py:119: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/autograph/converters/directives.py:119: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0603 04:14:52.794673 140665196312448 module_wrapper.py:139] From /tensorflow-1.15.2/python3.7/tensorflow_core/python/autograph/converters/directives.py:119: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /content/drive/MyDrive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/model.py:291: The name tf.trainable_variables is deprecated. Please use tf.compat.v1.trainable_variables instead.
#
# W0603 04:14:53.916570 140665196312448 module_wrapper.py:139] From /content/drive/MyDrive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/model.py:291: The name tf.trainable_variables is deprecated. Please use tf.compat.v1.trainable_variables instead.
#
# >>> total parameter: 5074868
# I0603 04:14:53.917303 140665196312448 model.py:293] >>> total parameter: 5074868
# WARNING:tensorflow:From /content/drive/MyDrive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/model.py:296: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See `tf.nn.softmax_cross_entropy_with_logits_v2`.
#
# W0603 04:14:53.918133 140665196312448 deprecation.py:323] From /content/drive/MyDrive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/model.py:296: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See `tf.nn.softmax_cross_entropy_with_logits_v2`.
#
# WARNING:tensorflow:From /content/drive/MyDrive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/model.py:315: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# W0603 04:14:53.968217 140665196312448 module_wrapper.py:139] From /content/drive/MyDrive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/model.py:315: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W0603 04:14:54.030311 140665196312448 deprecation.py:323] From /tensorflow-1.15.2/python3.7/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /content/drive/MyDrive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/model.py:327: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# W0603 04:14:56.837531 140665196312448 module_wrapper.py:139] From /content/drive/MyDrive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/model.py:327: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# WARNING:tensorflow:From /content/drive/MyDrive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/model.py:343: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# W0603 04:15:00.069077 140665196312448 module_wrapper.py:139] From /content/drive/MyDrive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/model.py:343: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# Traceback (most recent call last):
#   File "train_racl.py", line 86, in <module>
#     tf.app.run()
#   File "/tensorflow-1.15.2/python3.7/tensorflow_core/python/platform/app.py", line 40, in run
#     _run(main=main, argv=argv, flags_parser=_parse_flags_tolerate_undef)
#   File "/usr/local/lib/python3.7/dist-packages/absl/app.py", line 303, in run
#     _run_main(main, args)
#   File "/usr/local/lib/python3.7/dist-packages/absl/app.py", line 251, in _run_main
#     sys.exit(main(argv))
#   File "train_racl.py", line 81, in main
#     model.run()
#   File "/content/drive/MyDrive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/model.py", line 349, in run
#     saver.restore(sess, ckpt.model_checkpoint_path)
# AttributeError: 'NoneType' object has no attribute 'model_checkpoint_path'
# WARNING:tensorflow:From train_racl.py:86: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# Label / Unlabel Split
# sentence: labeled: 488, unlabeled: 1948
#
# target_polarity: labeled: 488, unlabeled: 1948
#
# target: labeled: 488, unlabeled: 1948
#
# opinion: labeled: 488, unlabeled: 1948
#
# Reuse Word Dictionary & Embedding
# -----------------------------------Parameters-----------------------------------
# I0603 04:15:03.453328 140698035799936 model.py:38] -----------------------------------Parameters-----------------------------------
# >>> model: racl
# >>> task: res14
# >>> batch_size: 8
# >>> learning_rate: 0.0001
# >>> global_dim: 300
# >>> domain_dim: 100
# >>> kp1: 0.5
# >>> kp2: 0.5
# >>> reg_scale: 1e-05
# >>> filter_num: 256
# >>> class_num: 3
# >>> load0: 1
# >>> load1: 0
# >>> num_students: 4
# >>> unlabeled_ratio: 0.8
# >>> shake_ratio: 0.1
# >>> confidence_thresh: 0.4
# >>> save0: 0
# >>> ckpt: 1
# >>> max_sentence_len: 80
# >>> n_iter: 80
# >>> kernel_size: 3
# >>> hop_num: 4
# >>> warmup_iter: 50
# >>> emb_dim: 400
# >>> data_path: data/res14/
# >>> train_path: data/res14/train_label/
# >>> test_path: data/res14/test/
# >>> dev_path: data/res14/dev/
# >>> n_iter_st: 80
# >>> unlabel_path: data/res14/train_unlabel/
#
#
# I0603 04:15:03.454095 140698035799936 model.py:39] >>> model: racl
# >>> task: res14
# >>> batch_size: 8
# >>> learning_rate: 0.0001
# >>> global_dim: 300
# >>> domain_dim: 100
# >>> kp1: 0.5
# >>> kp2: 0.5
# >>> reg_scale: 1e-05
# >>> filter_num: 256
# >>> class_num: 3
# >>> load0: 1
# >>> load1: 0
# >>> num_students: 4
# >>> unlabeled_ratio: 0.8
# >>> shake_ratio: 0.1
# >>> confidence_thresh: 0.4
# >>> save0: 0
# >>> ckpt: 1
# >>> max_sentence_len: 80
# >>> n_iter: 80
# >>> kernel_size: 3
# >>> hop_num: 4
# >>> warmup_iter: 50
# >>> emb_dim: 400
# >>> data_path: data/res14/
# >>> train_path: data/res14/train_label/
# >>> test_path: data/res14/test/
# >>> dev_path: data/res14/dev/
# >>> n_iter_st: 80
# >>> unlabel_path: data/res14/train_unlabel/
#
#
# WARNING:tensorflow:From /content/drive/My Drive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/model.py:46: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0603 04:15:03.479903 140698035799936 module_wrapper.py:139] From /content/drive/My Drive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/model.py:46: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/model.py:67: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# W0603 04:15:03.497896 140698035799936 deprecation.py:506] From /content/drive/My Drive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/model.py:67: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /content/drive/My Drive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/model.py:70: conv1d (from tensorflow.python.layers.convolutional) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.keras.layers.Conv1D` instead.
# W0603 04:15:03.505343 140698035799936 deprecation.py:323] From /content/drive/My Drive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/model.py:70: conv1d (from tensorflow.python.layers.convolutional) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.keras.layers.Conv1D` instead.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/layers/convolutional.py:218: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# W0603 04:15:03.506066 140698035799936 deprecation.py:323] From /tensorflow-1.15.2/python3.7/tensorflow_core/python/layers/convolutional.py:218: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From /content/drive/My Drive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/model.py:91: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# W0603 04:15:03.531757 140698035799936 module_wrapper.py:139] From /content/drive/My Drive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/model.py:91: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/utils.py:459: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W0603 04:15:03.724167 140698035799936 deprecation.py:323] From /content/drive/My Drive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/utils.py:459: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/autograph/converters/directives.py:119: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# W0603 04:15:03.952616 140698035799936 module_wrapper.py:139] From /tensorflow-1.15.2/python3.7/tensorflow_core/python/autograph/converters/directives.py:119: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/autograph/converters/directives.py:119: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0603 04:15:04.038413 140698035799936 module_wrapper.py:139] From /tensorflow-1.15.2/python3.7/tensorflow_core/python/autograph/converters/directives.py:119: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/model.py:291: The name tf.trainable_variables is deprecated. Please use tf.compat.v1.trainable_variables instead.
#
# W0603 04:15:05.108489 140698035799936 module_wrapper.py:139] From /content/drive/My Drive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/model.py:291: The name tf.trainable_variables is deprecated. Please use tf.compat.v1.trainable_variables instead.
#
# >>> total parameter: 5074868
# I0603 04:15:05.109218 140698035799936 model.py:293] >>> total parameter: 5074868
# WARNING:tensorflow:From /content/drive/My Drive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/model.py:296: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See `tf.nn.softmax_cross_entropy_with_logits_v2`.
#
# W0603 04:15:05.110103 140698035799936 deprecation.py:323] From /content/drive/My Drive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/model.py:296: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See `tf.nn.softmax_cross_entropy_with_logits_v2`.
#
# WARNING:tensorflow:From /content/drive/My Drive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/model.py:315: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# W0603 04:15:05.160486 140698035799936 module_wrapper.py:139] From /content/drive/My Drive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/model.py:315: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W0603 04:15:05.220271 140698035799936 deprecation.py:323] From /tensorflow-1.15.2/python3.7/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /content/drive/My Drive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/model.py:327: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# W0603 04:15:07.968558 140698035799936 module_wrapper.py:139] From /content/drive/My Drive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/model.py:327: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/model.py:343: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# W0603 04:15:11.182776 140698035799936 module_wrapper.py:139] From /content/drive/My Drive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/model.py:343: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# Traceback (most recent call last):
#   File "train_racl.py", line 86, in <module>
#     tf.app.run()
#   File "/tensorflow-1.15.2/python3.7/tensorflow_core/python/platform/app.py", line 40, in run
#     _run(main=main, argv=argv, flags_parser=_parse_flags_tolerate_undef)
#   File "/usr/local/lib/python3.7/dist-packages/absl/app.py", line 303, in run
#     _run_main(main, args)
#   File "/usr/local/lib/python3.7/dist-packages/absl/app.py", line 251, in _run_main
#     sys.exit(main(argv))
#   File "train_racl.py", line 81, in main
#     model.run()
#   File "/content/drive/My Drive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/model.py", line 349, in run
#     saver.restore(sess, ckpt.model_checkpoint_path)
# AttributeError: 'NoneType' object has no attribute 'model_checkpoint_path'
# WARNING:tensorflow:From train_racl.py:86: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# Label / Unlabel Split
# sentence: labeled: 488, unlabeled: 1948
#
# target_polarity: labeled: 488, unlabeled: 1948
#
# target: labeled: 488, unlabeled: 1948
#
# opinion: labeled: 488, unlabeled: 1948
#
# Reuse Word Dictionary & Embedding
# -----------------------------------Parameters-----------------------------------
# I0603 04:15:14.335740 140258997553024 model.py:38] -----------------------------------Parameters-----------------------------------
# >>> model: racl
# >>> task: res14
# >>> batch_size: 8
# >>> learning_rate: 0.0001
# >>> global_dim: 300
# >>> domain_dim: 100
# >>> kp1: 0.5
# >>> kp2: 0.5
# >>> reg_scale: 1e-05
# >>> filter_num: 256
# >>> class_num: 3
# >>> load0: 1
# >>> load1: 0
# >>> num_students: 4
# >>> unlabeled_ratio: 0.8
# >>> shake_ratio: 0.0
# >>> confidence_thresh: 0.4
# >>> save0: 0
# >>> ckpt: 1
# >>> max_sentence_len: 80
# >>> n_iter: 80
# >>> kernel_size: 3
# >>> hop_num: 4
# >>> warmup_iter: 50
# >>> emb_dim: 400
# >>> data_path: data/res14/
# >>> train_path: data/res14/train_label/
# >>> test_path: data/res14/test/
# >>> dev_path: data/res14/dev/
# >>> n_iter_st: 80
# >>> unlabel_path: data/res14/train_unlabel/
#
#
# I0603 04:15:14.336483 140258997553024 model.py:39] >>> model: racl
# >>> task: res14
# >>> batch_size: 8
# >>> learning_rate: 0.0001
# >>> global_dim: 300
# >>> domain_dim: 100
# >>> kp1: 0.5
# >>> kp2: 0.5
# >>> reg_scale: 1e-05
# >>> filter_num: 256
# >>> class_num: 3
# >>> load0: 1
# >>> load1: 0
# >>> num_students: 4
# >>> unlabeled_ratio: 0.8
# >>> shake_ratio: 0.0
# >>> confidence_thresh: 0.4
# >>> save0: 0
# >>> ckpt: 1
# >>> max_sentence_len: 80
# >>> n_iter: 80
# >>> kernel_size: 3
# >>> hop_num: 4
# >>> warmup_iter: 50
# >>> emb_dim: 400
# >>> data_path: data/res14/
# >>> train_path: data/res14/train_label/
# >>> test_path: data/res14/test/
# >>> dev_path: data/res14/dev/
# >>> n_iter_st: 80
# >>> unlabel_path: data/res14/train_unlabel/
#
#
# WARNING:tensorflow:From /content/drive/My Drive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/model.py:46: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0603 04:15:14.359032 140258997553024 module_wrapper.py:139] From /content/drive/My Drive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/model.py:46: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/model.py:67: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# W0603 04:15:14.375569 140258997553024 deprecation.py:506] From /content/drive/My Drive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/model.py:67: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /content/drive/My Drive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/model.py:70: conv1d (from tensorflow.python.layers.convolutional) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.keras.layers.Conv1D` instead.
# W0603 04:15:14.382862 140258997553024 deprecation.py:323] From /content/drive/My Drive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/model.py:70: conv1d (from tensorflow.python.layers.convolutional) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.keras.layers.Conv1D` instead.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/layers/convolutional.py:218: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# W0603 04:15:14.383585 140258997553024 deprecation.py:323] From /tensorflow-1.15.2/python3.7/tensorflow_core/python/layers/convolutional.py:218: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From /content/drive/My Drive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/model.py:91: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# W0603 04:15:14.409059 140258997553024 module_wrapper.py:139] From /content/drive/My Drive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/model.py:91: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/utils.py:459: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W0603 04:15:14.599153 140258997553024 deprecation.py:323] From /content/drive/My Drive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/utils.py:459: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/autograph/converters/directives.py:119: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# W0603 04:15:14.841094 140258997553024 module_wrapper.py:139] From /tensorflow-1.15.2/python3.7/tensorflow_core/python/autograph/converters/directives.py:119: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/autograph/converters/directives.py:119: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0603 04:15:14.930156 140258997553024 module_wrapper.py:139] From /tensorflow-1.15.2/python3.7/tensorflow_core/python/autograph/converters/directives.py:119: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/model.py:291: The name tf.trainable_variables is deprecated. Please use tf.compat.v1.trainable_variables instead.
#
# W0603 04:15:15.986471 140258997553024 module_wrapper.py:139] From /content/drive/My Drive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/model.py:291: The name tf.trainable_variables is deprecated. Please use tf.compat.v1.trainable_variables instead.
#
# >>> total parameter: 5074868
# I0603 04:15:15.987208 140258997553024 model.py:293] >>> total parameter: 5074868
# WARNING:tensorflow:From /content/drive/My Drive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/model.py:296: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See `tf.nn.softmax_cross_entropy_with_logits_v2`.
#
# W0603 04:15:15.988071 140258997553024 deprecation.py:323] From /content/drive/My Drive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/model.py:296: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See `tf.nn.softmax_cross_entropy_with_logits_v2`.
#
# WARNING:tensorflow:From /content/drive/My Drive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/model.py:315: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# W0603 04:15:16.037311 140258997553024 module_wrapper.py:139] From /content/drive/My Drive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/model.py:315: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W0603 04:15:16.096831 140258997553024 deprecation.py:323] From /tensorflow-1.15.2/python3.7/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /content/drive/My Drive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/model.py:327: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# W0603 04:15:18.877842 140258997553024 module_wrapper.py:139] From /content/drive/My Drive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/model.py:327: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/model.py:343: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# W0603 04:15:22.100624 140258997553024 module_wrapper.py:139] From /content/drive/My Drive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/model.py:343: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# Traceback (most recent call last):
#   File "train_racl.py", line 86, in <module>
#     tf.app.run()
#   File "/tensorflow-1.15.2/python3.7/tensorflow_core/python/platform/app.py", line 40, in run
#     _run(main=main, argv=argv, flags_parser=_parse_flags_tolerate_undef)
#   File "/usr/local/lib/python3.7/dist-packages/absl/app.py", line 303, in run
#     _run_main(main, args)
#   File "/usr/local/lib/python3.7/dist-packages/absl/app.py", line 251, in _run_main
#     sys.exit(main(argv))
#   File "train_racl.py", line 81, in main
#     model.run()
#   File "/content/drive/My Drive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_self/model.py", line 349, in run
#     saver.restore(sess, ckpt.model_checkpoint_path)
# AttributeError: 'NoneType' object has no attribute 'model_checkpoint_path'

# %%
# %cd /content/drive/MyDrive/"2021 봄학기"/"CS475 자연언어처리를 위한 기계학습"/Project/RACL_ss
# !CUDA_VISIBLE_DEVICES=0 python train_racl.py --task res14 --load 0 --sup_size 300 --unsup_ratio 8 --consistency_coeff 0 --alpha_sr 0.4 --confidence_thresh 0.7
# !CUDA_VISIBLE_DEVICES=0 python train_racl.py --task res14 --load 0 --sup_size 300 --unsup_ratio 8 --consistency_coeff 0 --alpha_sr 0.4 --confidence_thresh 0.7
# !CUDA_VISIBLE_DEVICES=0 python train_racl.py --task res14 --load 0 --sup_size 300 --unsup_ratio 8 --consistency_coeff 0 --alpha_sr 0.4 --confidence_thresh 0.7
# !CUDA_VISIBLE_DEVICES=0 python train_racl.py --task res14 --load 0 --sup_size 600 --unsup_ratio 8 --consistency_coeff 1 --alpha_sr 0.4 --confidence_thresh 0.7
# !CUDA_VISIBLE_DEVICES=0 python train_racl.py --task res14 --load 0 --sup_size 600 --unsup_ratio 8 --consistency_coeff 1 --alpha_sr 0.4 --confidence_thresh 0.7
# !CUDA_VISIBLE_DEVICES=0 python train_racl.py --task res14 --load 0 --sup_size 600 --unsup_ratio 8 --consistency_coeff 1 --alpha_sr 0.4 --confidence_thresh 0.7
# %cd /content/drive/MyDrive/RACL
# !CUDA_VISIBLE_DEVICES=0 python train_racl_a.py --task res14 --load 0
# Out:
# /content/drive/MyDrive/2021 봄학기/CS475 자연언어처리를 위한 기계학습/Project/RACL_ss
# python3: can't open file 'train_racl.py': [Errno 2] No such file or directory

# %%
# %env new_task=res14_300
# !python eda_nlp/code/augment.py --input=data/$new_task/unsup/train/sentence.txt --output=data/$new_task/aug/train/sentence.txt --num_aug=1 --alpha_sr=0.2 --alpha_rd=0.0 --alpha_ri=0.0 --alpha_rs=0.0
# !python eda_nlp/code/augment.py --input=data/$new_task/unsup/dev/sentence.txt --output=data/$new_task/aug/dev/sentence.txt --num_aug=1 --alpha_sr=0.2 --alpha_rd=0.0 --alpha_ri=0.0 --alpha_rs=0.0

# %%
# %pip install -U nltk
# !python
# import nltk; nltk.download('wordnet')
